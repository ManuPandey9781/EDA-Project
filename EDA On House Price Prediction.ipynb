# %% [markdown]
# # Description of columns from dataset documentation

# %% [markdown]
# ### Attributes:
# -     id :-                               int64
# -     Date :-                                  int64
# -    number of bedrooms :-                   int64
# -    number of bathrooms  :-                  float64
# -    living area :-                           int64
# -    lot area :-                              int64
# -    number of floors  :-                     float64
# -    waterfront present  :-                   int64
# -    number of views :-                       int64
# -    condition of the house :-                int64
# -    grade of the house :-                    int64
# -    Area of the house(excluding basement) :- int64
# -    Area of the basement :-                  int64
# -    Built Year  :-                           int64
# -    Renovation Year :-                       int64
# -    Postal Code :-                           int64
# -    Lattitude :-                             float64
# -    Longitude  :-                            float64
# -    living_area_renov :-                      int64
# -    lot_area_renov :-                        int64
# -    Number of schools nearby :-              int64
# -    Distance from the airport  :-            int64
# -    Price  :-                                int64

# %% [markdown]
# ##### There are four float values and 19 int values are present in the dataset.

# %% [markdown]
# #### reference of the dataset:-
# https://www.kaggle.com/datasets/mohamedafsal007/house-price-dataset-of-india

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading and Understanding the Dataset.

# %% [markdown]
# ### Import Dataset.

# %%
data=pd.read_csv('House Price India.csv')
df=pd.DataFrame(data)

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
# 2                       3  ...        1939                0       122004
# 3                       3  ...        2001                0       122005
# 4                       4  ...        1929                0       122006
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
# 2    52.8852   -114.468               2940            6600
# 3    52.9532   -114.321               3350           42847
# 4    52.9047   -114.485               2060            4500
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# 1                         2                         51  1400000
# 2                         1                         53  1200000
# 3                         3                         76   838000
# 4                         1                         51   805000
#
# [5 rows x 23 columns]

# %%
df.shape
# Out:
# (14620, 23)

# %% [markdown]
# #### From the above we can easily see that :-
# - The above dataset have 14620 rows and 23 columns in it.

# %%
df.tail(3)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 14617  6762830618  42734                   2                  1.0
# 14618  6762830709  42734                   4                  1.0
# 14619  6762831463  42734                   3                  1.0
#
#        living area  lot area  number of floors  waterfront present  \
# 14617         1070      6120               1.0                   0
# 14618         1030      6621               1.0                   0
# 14619          900      4770               1.0                   0
#
#        number of views  condition of the house  ...  Built Year  \
# 14617                0                       3  ...        1962
# 14618                0                       4  ...        1955
# 14619                0                       3  ...        1969
#
#        Renovation Year  Postal Code  Lattitude  Longitude  living_area_renov  \
# 14617                0       122056    52.7289   -114.507               1130
# 14618                0       122042    52.7157   -114.411               1420
# 14619             2009       122018    52.5338   -114.552                900
#
#        lot_area_renov  Number of schools nearby  Distance from the airport  \
# 14617            6120                         2                         64
# 14618            6631                         3                         54
# 14619            3480                         2                         55
#
#         Price
# 14617  209000
# 14618  205000
# 14619  146000
#
# [3 rows x 23 columns]

# %% [markdown]
# ### Discover Data.

# %%
rows,col = df.shape
print("Dimensions of Dataset:{}". format (df.shape))
print('Rows:',rows, '\n Columns:',col)
# Out:
# Dimensions of Dataset:(14620, 23)
# Rows: 14620
#  Columns: 23

# %%
# Statistical details
df.iloc[:, :-1].describe().T.sort_values(by='std' , ascending = False)\
                          .style.background_gradient(cmap='PuBu')\
                          .bar(subset=["max"], color='#F8766D')\
                          .bar(subset=["mean",], color='#00BFC4')
# Out:
# <style type="text/css">
# #T_6e473_row0_col0, #T_6e473_row0_col3, #T_6e473_row0_col4, #T_6e473_row0_col5, #T_6e473_row0_col6, #T_6e473_row1_col0, #T_6e473_row1_col3, #T_6e473_row1_col4, #T_6e473_row1_col5, #T_6e473_row1_col6, #T_6e473_row2_col0, #T_6e473_row3_col0, #T_6e473_row3_col3, #T_6e473_row3_col4, #T_6e473_row3_col5, #T_6e473_row3_col6, #T_6e473_row4_col0, #T_6e473_row4_col3, #T_6e473_row4_col4, #T_6e473_row4_col5, #T_6e473_row4_col6, #T_6e473_row5_col0, #T_6e473_row5_col3, #T_6e473_row5_col4, #T_6e473_row5_col5, #T_6e473_row5_col6, #T_6e473_row6_col0, #T_6e473_row6_col3, #T_6e473_row6_col4, #T_6e473_row6_col5, #T_6e473_row6_col6, #T_6e473_row7_col0, #T_6e473_row7_col3, #T_6e473_row7_col4, #T_6e473_row7_col5, #T_6e473_row7_col6, #T_6e473_row8_col0, #T_6e473_row8_col2, #T_6e473_row8_col3, #T_6e473_row8_col4, #T_6e473_row8_col5, #T_6e473_row8_col6, #T_6e473_row9_col0, #T_6e473_row9_col2, #T_6e473_row9_col3, #T_6e473_row9_col4, #T_6e473_row9_col5, #T_6e473_row9_col6, #T_6e473_row10_col0, #T_6e473_row10_col2, #T_6e473_row10_col3, #T_6e473_row10_col4, #T_6e473_row10_col5, #T_6e473_row10_col6, #T_6e473_row11_col0, #T_6e473_row11_col2, #T_6e473_row11_col3, #T_6e473_row11_col4, #T_6e473_row11_col5, #T_6e473_row11_col6, #T_6e473_row12_col0, #T_6e473_row12_col2, #T_6e473_row12_col3, #T_6e473_row12_col4, #T_6e473_row12_col5, #T_6e473_row12_col6, #T_6e473_row13_col0, #T_6e473_row13_col2, #T_6e473_row13_col3, #T_6e473_row13_col4, #T_6e473_row13_col5, #T_6e473_row13_col6, #T_6e473_row14_col0, #T_6e473_row14_col2, #T_6e473_row14_col3, #T_6e473_row14_col4, #T_6e473_row14_col5, #T_6e473_row14_col6, #T_6e473_row15_col0, #T_6e473_row15_col2, #T_6e473_row15_col3, #T_6e473_row15_col4, #T_6e473_row15_col5, #T_6e473_row15_col6, #T_6e473_row16_col0, #T_6e473_row16_col2, #T_6e473_row16_col3, #T_6e473_row16_col4, #T_6e473_row16_col5, #T_6e473_row16_col6, #T_6e473_row17_col0, #T_6e473_row17_col2, #T_6e473_row17_col3, #T_6e473_row17_col4, #T_6e473_row17_col5, #T_6e473_row17_col6, #T_6e473_row18_col0, #T_6e473_row18_col2, #T_6e473_row18_col3, #T_6e473_row18_col4, #T_6e473_row18_col5, #T_6e473_row18_col6, #T_6e473_row19_col0, #T_6e473_row19_col2, #T_6e473_row19_col3, #T_6e473_row19_col4, #T_6e473_row19_col5, #T_6e473_row19_col6, #T_6e473_row20_col0, #T_6e473_row20_col2, #T_6e473_row20_col3, #T_6e473_row20_col4, #T_6e473_row20_col5, #T_6e473_row20_col6, #T_6e473_row21_col0, #T_6e473_row21_col2, #T_6e473_row21_col3, #T_6e473_row21_col4, #T_6e473_row21_col5, #T_6e473_row21_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_6e473_row0_col1, #T_6e473_row1_col1, #T_6e473_row3_col1, #T_6e473_row4_col1, #T_6e473_row5_col1, #T_6e473_row6_col1, #T_6e473_row7_col1, #T_6e473_row8_col1, #T_6e473_row9_col1, #T_6e473_row10_col1, #T_6e473_row11_col1, #T_6e473_row12_col1, #T_6e473_row13_col1, #T_6e473_row14_col1, #T_6e473_row15_col1, #T_6e473_row16_col1, #T_6e473_row17_col1, #T_6e473_row18_col1, #T_6e473_row20_col1, #T_6e473_row21_col1 {
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.0%, #00BFC4 0.0%, #00BFC4 0.0%, transparent 0.0%);
# }
# #T_6e473_row0_col2, #T_6e473_row2_col3, #T_6e473_row2_col4, #T_6e473_row2_col5, #T_6e473_row2_col6 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6e473_row0_col7, #T_6e473_row1_col7, #T_6e473_row3_col7, #T_6e473_row4_col7, #T_6e473_row5_col7, #T_6e473_row6_col7, #T_6e473_row7_col7, #T_6e473_row8_col7, #T_6e473_row9_col7, #T_6e473_row10_col7, #T_6e473_row11_col7, #T_6e473_row12_col7, #T_6e473_row13_col7, #T_6e473_row14_col7, #T_6e473_row15_col7, #T_6e473_row16_col7, #T_6e473_row17_col7, #T_6e473_row18_col7, #T_6e473_row20_col7, #T_6e473_row21_col7 {
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.0%, #F8766D 0.0%, #F8766D 0.0%, transparent 0.0%);
# }
# #T_6e473_row1_col2 {
#   background-color: #1e80b8;
#   color: #f1f1f1;
# }
# #T_6e473_row2_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.0%, #00BFC4 0.0%, #00BFC4 100.0%, transparent 100.0%);
# }
# #T_6e473_row2_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_6e473_row2_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
#   width: 10em;
#   background: linear-gradient(90deg, transparent 0.0%, #F8766D 0.0%, #F8766D 100.0%, transparent 100.0%);
# }
# #T_6e473_row3_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_6e473_row4_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_6e473_row5_col2, #T_6e473_row6_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_6e473_row7_col2 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_6e473_row19_col1 {
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #00BFC4 0.0%, transparent 0.0%);
# }
# #T_6e473_row19_col7 {
#   background-color: #fff7fb;
#   color: #000000;
#   width: 10em;
#   background: linear-gradient(90deg, #F8766D 0.0%, transparent 0.0%);
# }
# </style>
# <table id="T_6e473">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e473_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_6e473_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_6e473_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_6e473_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_6e473_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_6e473_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_6e473_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_6e473_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e473_level0_row0" class="row_heading level0 row0" >lot area</th>
#       <td id="T_6e473_row0_col0" class="data row0 col0" >14620.000000</td>
#       <td id="T_6e473_row0_col1" class="data row0 col1" >15093.281122</td>
#       <td id="T_6e473_row0_col2" class="data row0 col2" >37919.621304</td>
#       <td id="T_6e473_row0_col3" class="data row0 col3" >520.000000</td>
#       <td id="T_6e473_row0_col4" class="data row0 col4" >5010.750000</td>
#       <td id="T_6e473_row0_col5" class="data row0 col5" >7620.000000</td>
#       <td id="T_6e473_row0_col6" class="data row0 col6" >10800.000000</td>
#       <td id="T_6e473_row0_col7" class="data row0 col7" >1074218.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6e473_level0_row1" class="row_heading level0 row1" >lot_area_renov</th>
#       <td id="T_6e473_row1_col0" class="data row1 col0" >14620.000000</td>
#       <td id="T_6e473_row1_col1" class="data row1 col1" >12753.500068</td>
#       <td id="T_6e473_row1_col2" class="data row1 col2" >26058.414467</td>
#       <td id="T_6e473_row1_col3" class="data row1 col3" >651.000000</td>
#       <td id="T_6e473_row1_col4" class="data row1 col4" >5097.750000</td>
#       <td id="T_6e473_row1_col5" class="data row1 col5" >7620.000000</td>
#       <td id="T_6e473_row1_col6" class="data row1 col6" >10125.000000</td>
#       <td id="T_6e473_row1_col7" class="data row1 col7" >560617.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6e473_level0_row2" class="row_heading level0 row2" >id</th>
#       <td id="T_6e473_row2_col0" class="data row2 col0" >14620.000000</td>
#       <td id="T_6e473_row2_col1" class="data row2 col1" >6762820830.525650</td>
#       <td id="T_6e473_row2_col2" class="data row2 col2" >6237.574799</td>
#       <td id="T_6e473_row2_col3" class="data row2 col3" >6762810020.000000</td>
#       <td id="T_6e473_row2_col4" class="data row2 col4" >6762815404.750000</td>
#       <td id="T_6e473_row2_col5" class="data row2 col5" >6762820822.500000</td>
#       <td id="T_6e473_row2_col6" class="data row2 col6" >6762826251.250000</td>
#       <td id="T_6e473_row2_col7" class="data row2 col7" >6762831616.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6e473_level0_row3" class="row_heading level0 row3" >living area</th>
#       <td id="T_6e473_row3_col0" class="data row3

# %% [markdown]
# #### The overhead table displays:
# - Each feature contains 14620 data recorded.
# - There is a negative value in the Longitude feature.

# %%
# Number of uniqe elements in each columns
unique = df.nunique()
unique.to_frame().T
# Out:
#       id  Date  number of bedrooms  number of bathrooms  living area  \
# 0  14620   241                  12                   29          865
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      7451                 6                   2                5
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...         116               68           70
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0       4662        716                665            6835
#
#    Number of schools nearby  Distance from the airport  Price
# 0                         3                         31   2901
#
# [1 rows x 23 columns]

# %%
# Information about the dataframe.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14620 entries, 0 to 14619
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   id                                     14620 non-null  int64
#  1   Date                                   14620 non-null  int64
#  2   number of bedrooms                     14620 non-null  int64
#  3   number of bathrooms                    14620 non-null  float64
#  4   living area                            14620 non-null  int64
#  5   lot area                               14620 non-null  int64
#  6   number of floors                       14620 non-null  float64
#  7   waterfront present                     14620 non-null  int64
#  8   number of views                        14620 non-null  int64
#  9   condition of the house                 14620 non-null  int64
#  10  grade of the house                     14620 non-null  int64
#  11  Area of the house(excluding basement)  14620 non-null  int64
#  12  Area of the basement                   14620 non-null  int64
#  13  Built Year                             14620 non-null  int64
#  14  Renovation Year                        14620 non-null  int64
#  15  Postal Code                            14620 non-null  int64
#  16  Lattitude                              14620 non-null  float64
#  17  Longitude                              14620 non-null  float64
#  18  living_area_renov                      14620 non-null  int64
#  19  lot_area_renov                         14620 non-null  int64
#  20  Number of schools nearby               14620 non-null  int64
#  21  Distance from the airport              14620 non-null  int64
#  22  Price                                  14620 non-null  int64
# dtypes: float64(4), int64(19)
# memory usage: 2.6 MB

# %%
# define the datatypes of the data.
df.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# lot_area_renov                             int64
# Number of schools nearby                   int64
# Distance from the airport                  int64
# Price                                      int64
# dtype: object

# %% [markdown]
# #### The information of the dataset shows:
# - Lattitude,Longitude ,number of floors and number of bathrooms  has an float type and the rest of the features have an int64 type.

# %% [markdown]
# ## Data Cleaning.

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# Price                                    0
# dtype: int64

# %% [markdown]
# ##### From above we can easily see that:-
# - There is no null value present in dataset.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### From above we can easily see that:-
# - There is no duplicate value present in data set.

# %%
df.head(3)
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# 0                       5  ...        1921                0       122003
# 1                       5  ...        1909                0       122004
# 2                       3  ...        1939                0       122004
#
#    Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0    52.8645   -114.557               2880            5400
# 1    52.8878   -114.470               2470            4000
# 2    52.8852   -114.468               2940            6600
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# 1                         2                         51  1400000
# 2                         1                         53  1200000
#
# [3 rows x 23 columns]

# %%
df.drop(['id','Date','Postal Code'],axis=1,inplace=True)

# %%
df.head(3)
# Out:
#    number of bedrooms  number of bathrooms  living area  lot area  \
# 0                   5                 2.50         3650      9050
# 1                   4                 2.50         2920      4000
# 2                   5                 2.75         2910      9480
#
#    number of floors  waterfront present  number of views  \
# 0               2.0                   0                4
# 1               1.5                   0                0
# 2               1.5                   0                0
#
#    condition of the house  grade of the house  \
# 0                       5                  10
# 1                       5                   8
# 2                       3                   8
#
#    Area of the house(excluding basement)  Area of the basement  Built Year  \
# 0                                   3370                   280        1921
# 1                                   1910                  1010        1909
# 2                                   2910                     0        1939
#
#    Renovation Year  Lattitude  Longitude  living_area_renov  lot_area_renov  \
# 0                0    52.8645   -114.557               2880            5400
# 1                0    52.8878   -114.470               2470            4000
# 2                0    52.8852   -114.468               2940            6600
#
#    Number of schools nearby  Distance from the airport    Price
# 0                         2                         58  2380000
# 1                         2                         51  1400000
# 2                         1                         53  1200000

# %%
df.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'waterfront present', 'number of views',
#        'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'Lattitude', 'Longitude',
#        'living_area_renov', 'lot_area_renov', 'Number of schools nearby',
#        'Distance from the airport', 'Price'],
#       dtype='object')

# %%
df.drop(['Lattitude','Longitude'],axis=1,inplace=True)

# %% [markdown]
# ### EDA Part:-

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %%
df.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'waterfront present', 'number of views',
#        'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
sns.countplot(data=df,x='number of bedrooms')
plt.title('Counting of Number Of Bedrooms')
plt.show()

# %% [markdown]
# ###### In the above Plot we can easily see that the
# - In Maximum No. of houses there are 3 Bedrooms.
# - The Houses where More than 7 bedrooms are less in count.

# %%
plt.figure(figsize=(14,8))
sns.countplot(data=df,x='number of bathrooms')
plt.title('Counting of Number Of Bathrooms')
plt.show()

# %% [markdown]
# ###### In the above Plot We can easily seen that
# - There are many Houses haveing 2.5 bathrooms.
# - and Houses haveing 1 bathroom lie on second Number.
# - Houses with 0.5,0.75,1.25, and more than 4.75 bathrooms are very less in count.

# %%
sns.countplot(data=df,x='number of floors')
plt.title('Counting of Number Of Floors')
plt.show()

# %% [markdown]
# ###### In the above Plot We can easily see that-
# - There are Maximum Number Of Houses haveing 1 Floor.

# %%
sns.countplot(data=df,x='waterfront present')
plt.title('Houses in which Waterfromnt present(1) or not(0)')
plt.show()

# %% [markdown]
# ###### In the above plot we can easily see that
# - There are more than 14,000 Houses haveing waterfront not present.
# - there are less Houses In which waterfront are present.

# %%
sns.countplot(data=df,x='number of views')
plt.title('Houses Haveing Number Of Views')
plt.show()

# %% [markdown]
# ###### From the above plot we can easily seen that
# - There are more than 12,000 houses haveing 0 views.
# - Houses haveing 1,4 views are less in Nature.

# %%
sns.countplot(data=df,x='condition of the house')
plt.title('Condition Of the Houses')
plt.show()

# %% [markdown]
# ###### From the above plot we can easily seen that
# -  More than 8000 Houses haveing medium condition(3).
# - There are less than 2000 Houses haveing excellent condition(5).

# %%
sns.countplot(data=df,x='grade of the house')
plt.title('Grade Of the Houses')
plt.show()

# %% [markdown]
# ###### From the above Plot we can easily see that
# - there are approx 6000 Houses haveing grade 7.
# - there are about less Houses haveing grade 4,12,13.

# %%
sns.countplot(data=df,x='Number of schools nearby')
plt.title(' Houses near to school')
plt.show()

# %% [markdown]
# ###### From the above plot we can easily see that
# - Maximum Number of 3 schools are present near the House.

# %%
plt.figure(figsize=(14,8))
sns.histplot(data=df,x='Distance from the airport')
plt.title('Houses haveing Distance form the AirPort')
plt.show()

# %% [markdown]
# ###### From above plot we can say that-
# - There are maximum number houses haveing distance 55km from the airport.

# %%
sns.displot(df['Price'])
plt.title('Distribution of Price')
plt.show()

# %% [markdown]
# ###### From the above plot we can say that
# - Maximum no. of Houses haveing Price in the range of (0-1).

# %%
sns.barplot(data=df,x='Number of schools nearby',y='Distance from the airport')
plt.title("Number of Schools VS Distance from the Airport")
plt.show()

# %% [markdown]
# ###### From the above Plot We can say that -
# - the distance between the schools and Airports have more than 60km.

# %%
df.columns
# Out:
# Index(['number of bedrooms', 'number of bathrooms', 'living area', 'lot area',
#        'number of floors', 'waterfront present', 'number of views',
#        'condition of the house', 'grade of the house',
#        'Area of the house(excluding basement)', 'Area of the basement',
#        'Built Year', 'Renovation Year', 'living_area_renov', 'lot_area_renov',
#        'Number of schools nearby', 'Distance from the airport', 'Price'],
#       dtype='object')

# %%
sns.lineplot(data=df,x='number of floors',y='number of bedrooms')
plt.title("Floor VS Bathroom")
plt.show()

# %% [markdown]
# ###### From the above Plot we can easily see that-
# - Floor haveing 2.5 and 3.5 haveing more number of bedrooms as comparison to the 3.0.

# %%
sns.barplot(data=df,x='number of bedrooms',y='number of bathrooms')
plt.title("Bedroom VS Bathroom")
plt.show()

# %% [markdown]
# ###### From the above plot we can easily see that-
# - 9 bedrooms haveing high number of bathrooms.
# - House haveing 1 Bedroom have 1 batroom.

# %%
sns.barplot(data=df,x='number of floors',y='number of views')
plt.title("Floor VS Views")
plt.show()

# %% [markdown]
# ###### From the above plot we can conclude that -
# - House haveing floor 2.5 and 3.5 haveing approx 0.5 number of views.

# %% [markdown]
# #### Conclusion:-
# -  In Maximum No. of houses there are 3 Bedrooms. and The Houses where More than 7 bedrooms are less in count.
# -  There are many Houses haveing 2.5 bathrooms.and Houses haveing 1 bathroom lie on second Number.& Houses with 0.5,0.75,1.25, and more than 4.75 bathrooms are very less in count.
# -  There are Maximum Number Of Houses haveing 1 Floor.
# -  9 bedrooms haveing high number of bathrooms. and House haveing 1 Bedroom have 1 batroom.
# -  House haveing floor 2.5 and 3.5 haveing approx 0.5 number of views.

# %% [markdown]
# ## ------------------------------- Thank you -------------------------------
